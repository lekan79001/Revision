# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 
# %matplotlib inline 
import seaborn as  sns
import chart_studio.plotly as py
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly.graph_objs as go

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
data = dict(type= 'choropleth', 
            locations= ["Az", "CA", "NY"], 
            locationmode= "USA-states", 
            colorscale= "tealrose", 
            text= ["Arizona","Cali","New York"], 
            z= [2.0,4.0,8.0],
            colorbar={"title":"USA-MAP"})

# %%
layout= dict(geo_scope= "usa")

# %%
choromap= go.Figure(data= [data], layout= layout)

# %%
iplot(choromap)
# Out:
# <div>                            <div id="65ad67ed-2c81-488f-a3c7-c4d07bf87dff" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("65ad67ed-2c81-488f-a3c7-c4d07bf87dff")) {                    Plotly.newPlot(                        "65ad67ed-2c81-488f-a3c7-c4d07bf87dff",                        [{"colorbar":{"title":{"text":"USA-MAP"}},"colorscale":[[0.0,"rgb(0, 147, 146)"],[0.16666666666666666,"rgb(114, 170, 161)"],[0.3333333333333333,"rgb(177, 199, 179)"],[0.5,"rgb(241, 234, 200)"],[0.6666666666666666,"rgb(229, 185, 173)"],[0.8333333333333334,"rgb(217, 137, 148)"],[1.0,"rgb(208, 88, 126)"]],"locationmode":"USA-states","locations":["Az","CA","NY"],"text":["Arizona","Cali","New York"],"z":[2.0,4.0,8.0],"type":"choropleth"}],                        {"geo"
# ...

# %%
data = dict(type= 'choropleth', 
            locations= ["Abj", "Lag", "Kan"], 
            locationmode= "country names", 
            colorscale= "magma", 
            text= ["Abuja", "Lagos","Kano"], 
            z= [8.0,6.0,10.0],
            colorbar={"title":"NIGERIAN-MAP"})

# %%
layout= dict(geo_scope= "africa")

# %%
mmap= go.Figure(data= [data], layout= layout)

# %%
iplot(mmap)
# Out:
# <div>                            <div id="38a7d5b4-c880-4c27-ad0d-f39412b8164d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("38a7d5b4-c880-4c27-ad0d-f39412b8164d")) {                    Plotly.newPlot(                        "38a7d5b4-c880-4c27-ad0d-f39412b8164d",                        [{"colorbar":{"title":{"text":"NIGERIAN-MAP"}},"colorscale":[[0.0,"#000004"],[0.1111111111111111,"#180f3d"],[0.2222222222222222,"#440f76"],[0.3333333333333333,"#721f81"],[0.4444444444444444,"#9e2f7f"],[0.5555555555555556,"#cd4071"],[0.6666666666666666,"#f1605d"],[0.7777777777777778,"#fd9668"],[0.8888888888888888,"#feca8d"],[1.0,"#fcfdbf"]],"locationmode":"country names","locations":["Abj","Lag","Kan"],"text":["Abuja","Lagos","Kano"],"z":[8.0,6.0,10.0],"type":"chor
# ...

# %%
ss = pd.read_excel(r"C:\Users\user\Desktop\TIMELINE\Desktop\Documents\POWER B.I\Sample - Superstore for Tableau 9.x versions.xlsx")

# %%
ss.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2013-152156 2013-11-09 2013-11-12    Second Class    CG-12520
# 1       2  CA-2013-152156 2013-11-09 2013-11-12    Second Class    CG-12520
# 2       3  CA-2013-138688 2013-06-13 2013-06-17    Second Class    DV-13045
# 3       4  US-2012-108966 2012-10-11 2012-10-18  Standard Class    SO-20335
# 4       5  US-2012-108966 2012-10-11 2012-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ... Region  \
# 0      Claire Gute   Consumer  United States        Henderson  ...  South
# 1      Claire Gute   Consumer  United States        Henderson  ...  South
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...   West
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
#
#         Product ID         Category Sub-Category  \
# ...

# %%
data = dict(type= "choropleth",
        colorscale= "magma",
        locations= ss["State-Code"],
        locationmode="USA-states",
        z= ss["Sales"],
        text= ss["Category"],
        colorbar= {"title":"SUPERSTORE USD"},
        marker= dict(line=dict(color="turquoise", width=2)))

# %%
layout= dict(title="SUPERSTORE ANALYSIS", geo = dict(scope= "usa", showlakes= True, lakecolor= "skyblue"))

# %%
ssmap = go.Figure(data= [data], layout= layout)

# %%
iplot(ssmap)
# Out:
# <div>                            <div id="5432b6f1-2c01-4044-ab1e-e90429c76772" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5432b6f1-2c01-4044-ab1e-e90429c76772")) {                    Plotly.newPlot(                        "5432b6f1-2c01-4044-ab1e-e90429c76772",                        [{"colorbar":{"title":{"text":"SUPERSTORE USD"}},"colorscale":[[0.0,"#000004"],[0.1111111111111111,"#180f3d"],[0.2222222222222222,"#440f76"],[0.3333333333333333,"#721f81"],[0.4444444444444444,"#9e2f7f"],[0.5555555555555556,"#cd4071"],[0.6666666666666666,"#f1605d"],[0.7777777777777778,"#fd9668"],[0.8888888888888888,"#feca8d"],[1.0,"#fcfdbf"]],"locationmode":"USA-states","locations":["KY","KY","CA","FL","FL","CA","CA","CA","CA","CA","CA","CA","NC","WA","TX","TX","WI
# ...

# %%
dvr = pd.read_excel("democratic_vs_republican_votes_by_usa_state_2020.xlsx")

# %%
dvr.head()
# Out:
#         state      DEM      REP   usa_state usa_state_code  percent_democrat
# 0     Alabama   843473  1434159     Alabama             AL         37.032892
# 1      Alaska    45758    80999      Alaska             AK         36.098993
# 2     Arizona  1643664  1626679     Arizona             AZ         50.259682
# 3    Arkansas   420985   761251    Arkansas             AR         35.609218
# 4  California  9315259  4812735  California             CA         65.934760

# %%
dvr.columns
# Out:
# Index(['state', 'DEM', 'REP', 'usa_state', 'usa_state_code',
#        'percent_democrat'],
#       dtype='object')

# %%
dvr = dict( type= "choropleth",
           colorscale= "winter",
           locationmode ="USA-states",
           locations= dvr["usa_state_code"],
           z= dvr["percent_democrat"],
           text= dvr["REP"],
           colorbar= {"title":"PERCENTAGE BAR"})

# %%
layout= dict(title= "ELECTION BY STATE", geo= dict(scope="usa", showlakes=True, lakecolor= "skyblue"))

# %%
dvrmap= go.Figure(data=[data], layout=layout)

# %%
plot(dvrmap)
# Out:
# 'temp-plot.html'

# %%
wec = pd.read_csv(r"C:\Users\user\Downloads\archive\2014_World_Power_Consumption")

# %%
wec.head()
# Out:
#          Country  Power Consumption KWH                        Text
# 0          China           5.523000e+12     China 5,523,000,000,000
# 1  United States           3.832000e+12    United 3,832,000,000,000
# 2       European           2.771000e+12  European 2,771,000,000,000
# 3         Russia           1.065000e+12    Russia 1,065,000,000,000
# 4          Japan           9.210000e+11       Japan 921,000,000,000

# %%
wec.info
# Out:
# <bound method DataFrame.info of            Country  Power Consumption KWH                        Text
# 0            China           5.523000e+12     China 5,523,000,000,000
# 1    United States           3.832000e+12    United 3,832,000,000,000
# 2         European           2.771000e+12  European 2,771,000,000,000
# 3           Russia           1.065000e+12    Russia 1,065,000,000,000
# 4            Japan           9.210000e+11       Japan 921,000,000,000
# ..             ...                    ...                         ...
# 214          Saint           7.440000e+06             Saint 7,440,000
# 215           Niue           2.790000e+06              Niue 2,790,000
# 216           Gaza           2.020000e+05                Gaza 202,000
# 217          Malta           1.747000e+05               Malta 174,700
# 218       Northern           4.830000e+04             Northern 48,300
#
# [219 rows x 3 columns]>

# %%
wec["Code"]= wec["Country"].str.split().str[0][:3]

# %%
wec
# Out:
#            Country  Power Consumption KWH                        Text  \
# 0            China           5.523000e+12     China 5,523,000,000,000
# 1    United States           3.832000e+12    United 3,832,000,000,000
# 2         European           2.771000e+12  European 2,771,000,000,000
# 3           Russia           1.065000e+12    Russia 1,065,000,000,000
# 4            Japan           9.210000e+11       Japan 921,000,000,000
# ..             ...                    ...                         ...
# 214          Saint           7.440000e+06             Saint 7,440,000
# 215           Niue           2.790000e+06              Niue 2,790,000
# 216           Gaza           2.020000e+05                Gaza 202,000
# 217          Malta           1.747000e+05               Malta 174,700
# 218       Northern           4.830000e+04             Northern 48,300
#
#          Code
# 0       China
# 1      United
# 2    European
# 3         NaN
# 4         NaN
# ..        ...
# 214       NaN
# ...

# %%
y = (lambda x:x.split()[:3])

# %%
wec["Code"] = (wec["Country"].apply(lambda Country:Country.split()[:3]))

# %%
wec["Code"].apply(y)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 wec["Code"].apply(y)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# ...
