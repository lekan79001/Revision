# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.linspace(0,5,11)
y = x ** 2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x,y,"p-")
plt.xlabel("X Label")
plt.ylabel("Y Label")
plt.title("Title")
# Out:
# Text(0.5, 1.0, 'Title')

# %%
 plt.subplot(1,2,1)
plt.plot(x,y,"r")
plt.xlabel("X Label")
plt.ylabel("Y Label")
plt.title("Title")

plt.subplot(1,2,2)
plt.plot(y,x,"b")
plt.xlabel("X Label")
plt.ylabel("Y Label")
plt.title("Title")
# Out:
# Text(0.5, 1.0, 'Title')

# %%
#OO
fig = plt.figure()
axes =fig.add_axes([0.3,0.3,0.8,0.8])
axes.plot(x,y)
plt.xlabel("X Label")
plt.ylabel("Y Label")
plt.title("Title")
# Out:
# Text(0.5, 1.0, 'Title')

# %%
fig = plt.figure()
axes1 = fig.add_axes([0.1,0.2,0.5,0.5])
axes2 = fig.add_axes([0.1,0.2,0.2,0.2])

axes1.plot(x,y)

axes1.set_title("LARGER PLOT")

axes2.plot(x,y)

axes2.set_title("SMALLER PLOT")
# Out:
# Text(0.5, 1.0, 'SMALLER PLOT')

# %%
ser = plt.figure()
axes = ser.add_axes([0.2,0.2,0.8,0.8])
axes. plot(x,y)
axes.set_xlabel("X label")
axes.set_ylabel("Y label")
axes.set_title("Title")
# Out:
# Text(0.5, 1.0, 'Title')

# %%
ser = plt.figure()
axes1 = ser.add_axes([0.2,0.2,0.6,0.6])
axes2 = ser.add_axes([0.3,0.4,0.2,0.3])

axes1. plot(x,y)
axes2. plot(y,x)

axes1.set_xlabel("X label")
axes2.set_xlabel("X label")

axes1.set_ylabel("Y label")
axes2.set_ylabel("Y label")

axes1.set_title("Title")
axes2.set_title("Title")
# Out:
# Text(0.5, 1.0, 'Title')

# %%
seq = plt.figure()

axes1 = seq.add_axes([0.1,0.2,0.5,0.5])
axes2 = seq.add_axes([0.0,0.0,0.4,0.4])

axes1.plot(x,y,"r-")
axes2.plot(y,x)

axes1.set_xlabel("X axis")
axes2.set_ylabel("Y axis")
axes1.set_xlabel("X axis")
axes2.set_ylabel("Y axis")

axes1.set_title("Graph")
axes2. set_title("Graph")
# Out:
# Text(0.5, 1.0, 'Graph')

# %%
fig,axes = plt.subplots(nrows = 1, ncols = 2)
for current_ax in axes:
    current_ax.plot(x,y)
    
axes[0].set_xlabel("X axis")
axes[1].set_xlabel("X axis")

axes[0].set_ylabel("Y axis")
axes[1].set_ylabel("Y axis")

axes[0].set_title("Graph")
axes [1].set_title("Graph")
# Out:
# Text(0.5, 1.0, 'Graph')

# %%
fig,axes = plt.subplots(nrows = 1, ncols = 2)

axes[0].plot(x,y,"r")
axes[0].set_title("First Graph")

axes[1].plot(y,x)
axes [1].set_title("Second Graph")

plt.tight_layout()

# %%
fig = plt.figure()
axes1 = fig.add_axes([0.2,0.3,0.3,0.5])
axes2 = fig.add_axes([0.0,0.1,0.4,0.6])

axes1.plot(x,y)
axes2.plot(y,x)
axes1.set_xlabel("X axis")
axes2.set_xlabel("X axis")

axes1.set_ylabel("Y axis")
axes2.set_ylabel("Y axis")

axes1.set_title("Graph 1")
axes2.set_title("Graph 2")
# Out:
# Text(0.5, 1.0, 'Graph 2')

# %%
fig,axes = plt.subplots(nrows = 2, ncols = 2)
for current_ax in axes:
    current_ax.plot(x,y)
    
axes[0].set_xlabel("X label")
axes[1].set_xlabel("X label")

axes[0].set_ylabel("Y label")
axes[1].set_ylabel("Y label")

axes[0].set_title("Graph 1")
axes[1].set_title("Graph 2")
plt.show()
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 3
#       1 fig,axes = plt.subplots(nrows = 2, ncols = 2)
#       2 for current_ax in axes:
# ----> 3     current_ax.plot(x,y)
#       5 axes[0].set_xlabel("X label")
#       6 axes[1].set_xlabel("X label")
#
# AttributeError: 'numpy.ndarray' object has no attribute 'plot'

# %%
fig,axes = plt.subplots(nrows = 1, ncols = 2)

axes[0].plot(x,y,"r")
axes[0].set_xlabel("X axis")
axes[0].set_ylabel("Y axis")
axes[0].set_title("Graph 1")


axes[1].plot(y,x)
axes[1].set_xlabel("X axis")
axes[1].set_ylabel("Y label")
axes[1].set_title("Graph 2")

plt.tight_layout()

# %%
fig,axes = plt.subplots(nrows = 1, ncols = 2)

axes[0].plot(x,y,"g")
axes[0].set_xlabel("X axis")
axes[0].set_ylabel("Y axis")
axes[0].set_title("Graph 1")

axes[1].plot(y,x,"p")
axes[1].set_xlabel("X axis")
axes[1].set_ylabel("Y axis")
axes[1].set_title("Graph 2")
# Out:
# Text(0.5, 1.0, 'Graph 2')

# %%
fig = plt.figure()
axes= fig.add_axes([0.1,0.2,0.3,0.4])
axes1 = fig.add_axes([0.0,0.2,0.2,0.6])
axes.plot(x,y)
axes1.plot(x,y)
axes.set_xlabel("X label")
axes.set_xlabel("X label")
axes.set_title("GRAPH 1")

axes1.set_xlabel("X label")
axes1.set_ylabel("Y label")
axes1.set_title("Graph 2")
# Out:
# Text(0.5, 1.0, 'Graph 2')

# %%
fig,axes = plt.subplots (nrows = 2, ncols = 2)
axes.plot(x,y,"p")
axes.set_xlabel("X axis")
axes.set_ylabel("Y axis")
axes.set_title("graph 1")

axes1.plot(y,x,"y")
axes1.set_xlabel("X axis")
axes1.set_ylabel("Y axis")
axes1.set_title("graph s")
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[36], line 2
#       1 fig,axes = plt.subplots (nrows = 2, ncols = 2)
# ----> 2 axes.plot(x,y,"p")
#       3 axes.set_xlabel("X axis")
#       4 axes.set_ylabel("Y axis")
#
# AttributeError: 'numpy.ndarray' object has no attribute 'plot'

# %%
fig = plt.figure(figsize = (6,2))
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)

# %%
fig,axes = plt.subplots(nrows = 2, ncols = 1, figsize = (8,4))
axes[0].plot(x,y,"r")
axes[1].plot(y,x,"p")
plt.tight_layout()

# %%
fig

# %%
fig.savefig("my pics", dpi = 150)

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,2,2])
ax.plot(x,y,label = "squared")
ax.plot(y,x,label = "cubed")
ax.legend(loc = 0)

# %%
fig,ax = plt.subplots(nrows = 2, ncols = 1, figsize = (6,3))
ax[1].plot(x,y,label= "one")
ax[1].plot(y,x,label = "two")
ax[1].set_xlabel("X")
ax[1].set_ylabel("Y")
ax[1].set_title("A")
ax[1].legend(loc = 0)

ax[2].plot(x,y,label= "three")
ax[2].plot(y,x,label = "four")
ax[2].set_xlabel("X")
ax[2].set_ylabel("Y")
ax[2].set_title("A")
ax[2].legend(loc = 0)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[31], line 9
#       6 ax[1].set_title("A")
#       7 ax[1].legend(loc = 0)
# ----> 9 ax[2].plot(x,y,label= "three")
#      10 ax[2].plot(y,x,label = "four")
#      11 ax[2].set_xlabel("X")
#
# IndexError: index 2 is out of bounds for axis 0 with size 2

# %%
fig = plt.figure(figsize = (4,2))
ax = fig.add_axes([0,0,2,3])

ax.plot(x, x *2,"-.", label = "SQUARED",lw=2, marker = "1", markersize = 1 )
ax.plot(x, x*3,"b:", label = "CUBED")
ax.legend(loc = 10)

# %%
fig= plt.figure(figsize = (2,2))
as1 = fig.add_axes([0,2,4,6])
as1. plot(x,y,"r",lw= 2, markersize = 10,label = "LEGEND", ls= ":", marker = "+", markerfacecolor = "yellow",markeredgecolor ="black",markeredgewidth = 3)
as1.legend(loc = 0)
as1.set_title("GRAPH")
as1.set_xlim([0,6])
as1.set_ylim([0,3])
# Out:
# (0.0, 3.0)

# %%
plt.scatter(x,y)

# %%
import numpy as np
x = np.arange(10,100)
y = x*2
z = x**2

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig = plt.subplots(nrows =1, ncols = 2, figsize = (3,3))


axes.plot(x,y,ls= ":", marker = "+", label = "LEGEND")
axes1.plot(x,y,ls= ":", marker = "+", label = "LEGEND")
axes.set_xlabel("X")
axes.set_ylabel("Y")
axes1.set_xlabel("X")
axes1.set_ylabel("Y")
axes.set_title("Graph 1")
axes1.set_title("Graph 2")
axes.legend(loc = 0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 4
#       1 fig = plt.subplots(nrows =1, ncols = 2, figsize = (3,3))
# ----> 4 axes.plot(x,y,ls= ":", marker = "+", label = "LEGEND")
#       5 axes1.plot(x,y,ls= ":", marker = "+", label = "LEGEND")
#       6 axes.set_xlabel("X")
#
# NameError: name 'axes' is not defined

# %%
fig = plt.figure()
ax = fig.add_axes([0,0.3,0.6,0.8])
ax.plot(x,y,label = "legend",marker= "*",ls= ":", color = "red")
ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_title("GRAPH")
ax.legend(loc = 3)

# %%
pip install seaborn
# Out:
# ...
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    - -------------------------------------- 10.2/294.9 kB ? eta -:--:--
#    - -------------------------------------- 10.2/294.9 kB ? eta -:--:--
#    ---- ---------------------------------- 30.7/294.9 kB 163.8 kB/s eta 0:00:02
#    ----- --------------------------------- 41.0/294.9 kB 195.7 kB/s eta 0:00:02
#    -------- ------------------------------ 61.4/294.9 kB 252.2 kB/s eta 0:00:01
#    ------------ -------------------------- 92.2/294.9 kB 327.7 kB/s eta 0:00:01
#    ------------------ ------------------- 143.4/294.9 kB 448.2 kB/s eta 0:00:01
#    ------------------- ------------------ 153.6/294.9 kB 458.0 kB/s eta 0:00:01
#    ------------------------------- ------ 245.8/294.9 kB 602.4 kB/s eta 0:00:01
#    ------------------------------------ - 286.7/294.9 kB 655.2 kB/s eta 0:00:01
# ...

# %%
pip install plotly
# Out:
# ...
#    ---------------------------------------- 0.0/19.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/19.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/19.1 MB 435.7 kB/s eta 0:00:44
#    ---------------------------------------- 0.0/19.1 MB 326.8 kB/s eta 0:00:59
#    ---------------------------------------- 0.1/19.1 MB 476.3 kB/s eta 0:00:40
#    ---------------------------------------- 0.1/19.1 MB 607.9 kB/s eta 0:00:32
#    ---------------------------------------- 0.2/19.1 MB 692.4 kB/s eta 0:00:28
#     --------------------------------------- 0.4/19.1 MB 1.0 MB/s eta 0:00:18
#     --------------------------------------- 0.5/19.1 MB 1.1 MB/s eta 0:00:18
#     --------------------------------------- 0.5/19.1 MB 1.1 MB/s eta 0:00:18
#    - -------------------------------------- 0.5/19.1 MB 1.0 MB/s eta 0:00:19
#    - -------------------------------------- 0.7/19.1 MB 1.2 MB/s eta 0:00:16
# ...

# %%
pip install cufflinks
# Out:
# ...
#
# ...
#      ---------------------------------------- 0.0/81.7 kB ? eta -:--:--
#      ----- ---------------------------------- 10.2/81.7 kB ? eta -:--:--
#      ----- ---------------------------------- 10.2/81.7 kB ? eta -:--:--
#      --------- ---------------------------- 20.5/81.7 kB 108.9 kB/s eta 0:00:01
#      --------- ---------------------------- 20.5/81.7 kB 108.9 kB/s eta 0:00:01
#      -------------- ----------------------- 30.7/81.7 kB 119.1 kB/s eta 0:00:01
#      ------------------- ------------------ 41.0/81.7 kB 151.3 kB/s eta 0:00:01
#      ---------------------------- --------- 61.4/81.7 kB 204.8 kB/s eta 0:00:01
#      --------------------------------- ---- 71.7/81.7 kB 206.9 kB/s eta 0:00:01
#      --------------------------------- ---- 71.7/81.7 kB 206.9 kB/s eta 0:00:01
#      --------------------------------- ---- 71.7/81.7 kB 206.9 kB/s eta 0:00:01
#      -------------------------------------- 81.7/81.7 kB 163.6 kB/s eta 0:00:00
# ...

# %%
pip install upgrade pip
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x000002015562DDF0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/upgrade/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x00000201555F9940>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/upgrade/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x00000201568B5820>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/upgrade/
# ...

# %%
x = [1,2,3,4]
y = [2,4,6,8]

import matplotlib.pyplot as plt
# %matplotlib inline

dia = plt.figure()

ax1 = dia.add_axes([0.1,0.2,0.4,0.6])
ax2 = dia.add_axes([0.2,0.3,0.2,0.3])


ax1.plot(x,y,"b-")
ax1.set_xlabel("X-axis")
ax1.set_ylabel("Y-axis")
ax1.set_title("Graph 1")

ax2.plot(y,x)
ax2.set_xlabel("X-axis")
ax2.set_ylabel("Y-axis")
ax2.set_title("Graph 2")
# Out:
# Text(0.5, 1.0, 'Graph 2')

# %%
x= [2,4,6,8,10]
y = [5,10,15,20,25]
import matplotlib.pyplot as plt
# %matplotlib inline

st = plt.figure(figsize = (1,3))

ax1 = st.add_axes([0,0.3,0.6,0.7])
ax2 = st.add_axes([0.2,0.4,0.4,0.5])

ax1. plot(x,y)


ax2.plot(y,x)

# %%
fig = plt.figure(figsize = (3,6))
axes1 = fig.add_axes([0.2,0.3,0.3,0.5])
axes2 = fig.add_axes([0.0,0.1,0.4,0.6])

axes1.plot(x,y)
axes2.plot(y,x)
axes1.set_xlabel("X axis")
axes2.set_xlabel("X axis")

axes1.set_ylabel("Y axis")
axes2.set_ylabel("Y axis")

axes1.set_title("Graph 1")
axes2.set_title("Graph 2")
# Out:
# Text(0.5, 1.0, 'Graph 2')

# %%
fin = plt.figure( figsize = (8,4),dpi = 120)
ax1 = fin.add_axes([0,0.3,0.6,0.8])
ax2 = fin.add_axes([0.1,0.5,0.5,0.4])

ax1.plot(x,y,"r-")
ax2.plot(y,x,"b:")

ax1.set_xlabel("X-axis")
ax1.set_ylabel("Y-axis")
ax1.set_title("GRAPH 1")



ax2.set_xlabel("X-axis")
axes2.set_ylabel("Y-axis")
ax2.set_title("GRAPH 2")
# Out:
# Text(0.5, 1.0, 'GRAPH 2')

# %%
fig,ax = plt.subplots(nrows =1, ncols = 4, figsize = (8,4), dpi = 120)

ax[0].plot(x,y, label = "LEGEND", lw = 8, alpha = 0.8, ls = "--", marker = "o", markersize = 10)
ax[0].set_xlabel("X-axis")
ax[0].set_ylabel("Y-axis")
ax[0].set_title("Graph ")
ax[0].set_xlim([0,5])
ax[0].set_ylim([2,10])
ax[0].legend(loc = 0)


ax[1].plot(x,y, label = "LEGEND",  color = "red", ls = ":", lw = 3, alpha = 0.6, marker = "*", markerfacecolor = "blue", markeredgecolor = "green", markeredgewidth = 5)
ax[1].set_xlabel("X-axis")
ax[1].set_ylabel("Y-axis")
ax[1].set_title("Graph 1")
ax[1].set_xlim([0,5])
ax[1].set_ylim([2,10])
ax[1].legend(loc = 0)


ax[2].plot(x,y, label = "LEGEND", linewidth = 5, alpha = 0.5, ls = "-.", marker = "+")
ax[2].set_xlabel("X-axis")
ax[2].set_ylabel("Y-axis")
ax[2].set_title("Graph 2")
ax[2].set_xlim([0,5])
ax[2].set_ylim([2,10])
ax[2].legend(loc = 0)


ax[3].plot(x,y, "r-", label = "LEGEND", linewidth = 5, alpha = 0.5,marker= "1" )
ax[3].set_xlabel("X-axis")
ax[3].set_ylabel("Y-axis")
ax[3].set_title("Graph 3")
ax[3].set_xlim([0,5])
ax[3].set_ylim([2,10])
ax[3].legend(loc = 0)



plt.tight_layout()

# %%
fig.savefig("my_pics.png")

# %%
my_pics.png()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 my_pics.png()
#
# NameError: name 'my_pics' is not defined

# %%
dia = plt.figure(figsize = (8,3), dpi = 100)

ax = dia.add_axes([0,0.2,0.4,0.6])

ax.plot(x,x, label = "legend")
ax.plot(y,y, label = "legend")

ax.legend(loc = 0)

# %%
dia = plt.figure( )

ax = dia.add_axes([0,0,1,1])

ax.plot(x,y)
ax.set_xlim([0,1])
ax.set_ylim([0,2])
# Out:
# (0.0, 2.0)

# %%
fig = plt.figure()

ax1 = fig.add_axes([0.1,0.2,0.4,0.6])
ax2 = fig.add_axes([0.2,0.3,0.2,0.3])


ax1.plot(x,y,"b-")
ax1.set_xlabel("X-axis")
ax1.set_ylabel("Y-axis")
ax1.set_title("Graph 1")

ax2.plot(y,x)
ax2.set_xlabel("X-axis")
ax2.set_ylabel("Y-axis")
ax2.set_title("Graph 2")
# Out:
# Text(0.5, 1.0, 'Graph 2')

# %%
x = np.arange(0,10)
y = np.arange(0,20,2)
import matplotlib.pyplot as plt
# %matplotlib inline

dia = plt.figure()

ax1 = dia.add_axes([0.1,0.2,0.4,0.6])
ax2 = dia.add_axes([0.2,0.3,0.2,0.3])


ax1.plot(x,y,"b-")
ax1.set_xlabel("X-axis")
ax1.set_ylabel("Y-axis")
ax1.set_title("Graph 1")

ax2.plot(y,x)
ax2.set_xlabel("X-axis")
ax2.set_ylabel("Y-axis")
ax2.set_title("Graph 2")
# Out:
# Text(0.5, 1.0, 'Graph 2')

# %%
import numpy as np
x = np.linspace(0,10,5)
y = np.arange(0,10,2)
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize = (8,4))

ax1 = fig.add_axes([0.1,0.2,0.4,0.6])
ax2 = fig.add_axes([0.2,0.3,0.2,0.3])


ax1.plot(x,y,"b:", marker = "*", label = "LEGEND")
ax1.set_xlabel("X-axis")
ax1.set_ylabel("Y-axis")
ax1.set_title("Graph 1")
ax1.legend(loc = 0)

ax2.plot(y,x,"r-.", marker = "+", label = "LEGEND")
ax2.set_xlabel("X-axis")
ax2.set_ylabel("Y-axis")
ax2.set_title("Graph 2")
ax2.legend(loc = 5)
