# %%
import numpy as np
import pandas as pd

# %%
spf = pd.read_csv(r"C:\Users\user\Downloads\archive\StudentPerformanceFactors.csv")
spf
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                       68.95   35     61833.90                256.09
# 1                       80.23   31     68441.85                193.77
# 2                       69.47   26     59785.94                236.50
# 3                       74.15   29     54806.18                245.89
# 4                       68.37   35     73889.99                225.58
# ..                        ...  ...          ...                   ...
# 995                     72.97   30     71384.57                208.58
# 996                     51.30   45     67782.17                134.42
# 997                     51.63   51     42415.72                120.37
# 998                     55.55   19     41920.79                187.95
# 999                     45.01   26     29875.80                178.35
#
#                              Ad Topic Line            City  Male  \
# ...

# %%
spf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Daily Time Spent on Site  1000 non-null   float64
#  1   Age                       1000 non-null   int64
#  2   Area Income               1000 non-null   float64
#  3   Daily Internet Usage      1000 non-null   float64
#  4   Ad Topic Line             1000 non-null   object
#  5   City                      1000 non-null   object
#  6   Male                      1000 non-null   int64
#  7   Country                   1000 non-null   object
#  8   Timestamp                 1000 non-null   object
#  9   Clicked on Ad             1000 non-null   int64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 78.3+ KB

# %%
spf.shape
# Out:
# (1000, 10)

# %%
spf.head(20)
# Out:
#     Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                      68.95   35     61833.90                256.09
# 1                      80.23   31     68441.85                193.77
# 2                      69.47   26     59785.94                236.50
# 3                      74.15   29     54806.18                245.89
# 4                      68.37   35     73889.99                225.58
# 5                      59.99   23     59761.56                226.74
# 6                      88.91   33     53852.85                208.36
# 7                      66.00   48     24593.33                131.76
# 8                      74.53   30     68862.00                221.51
# 9                      69.88   20     55642.32                183.82
# 10                     47.64   49     45632.51                122.02
# 11                     83.07   37     62491.01                230.87
# 12                     69.57   48     51636.92                113.12
# ...

# %%
spf.tail(20)
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 980                     67.26   57     25682.65                168.41
# 981                     76.58   46     41884.64                258.26
# 982                     54.37   38     72196.29                140.77
# 983                     82.79   32     54429.17                234.81
# 984                     66.47   31     58037.66                256.39
# 985                     72.88   44     64011.26                125.12
# 986                     76.44   28     59967.19                232.68
# 987                     63.37   43     43155.19                105.04
# 988                     89.71   48     51501.38                204.40
# 989                     70.96   31     55187.85                256.40
# 990                     35.79   44     33813.08                165.62
# 991                     38.96   38     36497.22                140.67
# ...

# %%
spf.sum()["Male"]
# Out:
# 481

# %%
spf[spf["Male"]== 30].count()
# Out:
# Daily Time Spent on Site    0
# Age                         0
# Area Income                 0
# Daily Internet Usage        0
# Ad Topic Line               0
# City                        0
# Male                        0
# Country                     0
# Timestamp                   0
# Clicked on Ad               0
# dtype: int64

# %%
spf["Age"]
# Out:
# 0      35
# 1      31
# 2      26
# 3      29
# 4      35
#        ..
# 995    30
# 996    45
# 997    51
# 998    19
# 999    26
# Name: Age, Length: 1000, dtype: int64

# %%
spf["Age"][200:500]
# Out:
# 200    40
# 201    29
# 202    40
# 203    31
# 204    29
#        ..
# 495    35
# 496    29
# 497    39
# 498    27
# 499    37
# Name: Age, Length: 300, dtype: int64

# %%
spf["Age"].min()
# Out:
# 19

# %%
spf["Age"].max()
# Out:
# 61

# %%
spf["Age"].mean()
# Out:
# 36.009

# %%
spf.describe().transpose()
# Out:
#                            count         mean           std       min  \
# Daily Time Spent on Site  1000.0     65.00020     15.853615     32.60
# Age                       1000.0     36.00900      8.785562     19.00
# Area Income               1000.0  55000.00008  13414.634022  13996.50
# Daily Internet Usage      1000.0    180.00010     43.902339    104.78
# Male                      1000.0      0.48100      0.499889      0.00
# Clicked on Ad             1000.0      0.50000      0.500250      0.00
#
#                                  25%        50%         75%       max
# Daily Time Spent on Site     51.3600     68.215     78.5475     91.43
# Age                          29.0000     35.000     42.0000     61.00
# Area Income               47031.8025  57012.300  65470.6350  79484.80
# Daily Internet Usage        138.8300    183.130    218.7925    269.96
# Male                          0.0000      0.000      1.0000      1.00
# ...

# %%
spf[["Age","Area Income"]].corr()
# Out:
#                   Age  Area Income
# Age          1.000000    -0.182605
# Area Income -0.182605     1.000000

# %%
spf.columns
# Out:
# Index(['Daily Time Spent on Site', 'Age', 'Area Income',
#        'Daily Internet Usage', 'Ad Topic Line', 'City', 'Male', 'Country',
#        'Timestamp', 'Clicked on Ad'],
#       dtype='object')

# %%
spf[["Country","City"]].nunique()
# Out:
# Country    237
# City       969
# dtype: int64

# %%
spf.groupby("Daily Time Spent on Site").describe().transpose()
# Out:
# Daily Time Spent on Site           32.60     32.84     32.91     32.99  \
# Age                  count      2.000000      1.00      1.00      1.00
#                      mean      41.500000     40.00     37.00     45.00
#                      std        4.949747       NaN       NaN       NaN
#                      min       38.000000     40.00     37.00     45.00
#                      25%       39.750000     40.00     37.00     45.00
#                      50%       41.500000     40.00     37.00     45.00
#                      75%       43.250000     40.00     37.00     45.00
#                      max       45.000000     40.00     37.00     45.00
# Area Income          count      2.000000      1.00      1.00      1.00
#                      mean   44182.620000  41232.89  51691.55  49282.87
#                      std     5689.975131       NaN       NaN       NaN
#                      min    40159.200000  41232.89  51691.55  49282.87
# ...

# %%
spf["Age"].argmax()
# Out:
# 671

# %%
spf["Age"].argmin()
# Out:
# 349

# %%
spf["Age"].idxmax()
# Out:
# 671

# %%
spf["Age"].idxmin()
# Out:
# 349

# %%
spf.rank()[["Country","Area Income"]]
# Out:
#      Country  Area Income
# 0      897.5        646.0
# 1      637.0        854.0
# 2      779.0        576.0
# 3      460.0        438.0
# 4      433.0        956.0
# ..       ...          ...
# 995    511.5        915.0
# 996    120.0        840.0
# 997    618.5        179.0
# 998    391.5        171.0
# 999    131.0         59.0
#
# [1000 rows x 2 columns]

# %%
spf.rank()["Age"]
# Out:
# 0      503.0
# 1      333.5
# 2      117.0
# 3      240.5
# 4      503.0
#        ...
# 995    284.0
# 996    828.5
# 997    934.5
# 998      3.5
# 999    117.0
# Name: Age, Length: 1000, dtype: float64

# %%
spf.rank()["Country"]
# Out:
# 0      897.5
# 1      637.0
# 2      779.0
# 3      460.0
# 4      433.0
#        ...
# 995    511.5
# 996    120.0
# 997    618.5
# 998    391.5
# 999    131.0
# Name: Country, Length: 1000, dtype: float64

# %%
spf["Country"].value_counts().head(20)
# Out:
# Country
# France            9
# Czech Republic    9
# Peru              8
# Turkey            8
# Greece            8
# Senegal           8
# Liberia           8
# Australia         8
# South Africa      8
# Micronesia        8
# Cyprus            8
# Afghanistan       8
# Taiwan            7
# Cambodia          7
# Luxembourg        7
# Eritrea           7
# Fiji              7
# Burundi           7
# Venezuela         7
# Bahamas           7
# Name: count, dtype: int64

# %%
len(spf.columns)
# Out:
# 10

# %%
len(spf.index)
# Out:
# 1000

# %%
spf.head()
# Out:
#    Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                     68.95   35     61833.90                256.09
# 1                     80.23   31     68441.85                193.77
# 2                     69.47   26     59785.94                236.50
# 3                     74.15   29     54806.18                245.89
# 4                     68.37   35     73889.99                225.58
#
#                            Ad Topic Line            City  Male     Country  \
# 0     Cloned 5thgeneration orchestration     Wrightburgh     0     Tunisia
# 1     Monitored national standardization       West Jodi     1       Nauru
# 2       Organic bottom-line service-desk        Davidton     0  San Marino
# 3  Triple-buffered reciprocal time-frame  West Terrifurt     1       Italy
# 4          Robust logistical utilization    South Manuel     0     Iceland
#
#           Timestamp  Clicked on Ad
# 0   27/03/2016 0:53              0
# ...

# %%
spf[spf["Male"] ==  0].count()
# Out:
# Daily Time Spent on Site    519
# Age                         519
# Area Income                 519
# Daily Internet Usage        519
# Ad Topic Line               519
# City                        519
# Male                        519
# Country                     519
# Timestamp                   519
# Clicked on Ad               519
# dtype: int64

# %%
spf[spf["Male"] ==0]["Male"].count()
# Out:
# 519

# %%
spf[spf["Country"]=="Tunisia"]["Age"]
# Out:
# 0      35
# 41     30
# 68     25
# 910    52
# Name: Age, dtype: int64

# %%
spf[spf["Country"]=="Tunisia"].count()
# Out:
# Daily Time Spent on Site    4
# Age                         4
# Area Income                 4
# Daily Internet Usage        4
# Ad Topic Line               4
# City                        4
# Male                        4
# Country                     4
# Timestamp                   4
# Clicked on Ad               4
# dtype: int64

# %%
spf[spf["Country"]=="Tunisia"].value_counts()
# Out:
# Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  Ad Topic Line                       City               Male  Country  Timestamp         Clicked on Ad
# 42.84                     52   27073.27     182.20                Enhanced optimizing website         Lake Michellebury  1     Tunisia  21/03/2016 11:02  1                1
# 64.24                     30   59784.18     252.36                Front-line intermediate database    Zacharystad        0     Tunisia  16/04/2016 11:53  0                1
# 68.95                     35   61833.90     256.09                Cloned 5thgeneration orchestration  Wrightburgh        0     Tunisia  27/03/2016 0:53   0                1
# 75.74                     25   61005.87     215.25                Ergonomic multi-state structure     New Sheila         1     Tunisia  16/01/2016 11:35  0                1
# Name: count, dtype: int64

# %%
spf.rank()["Area Income"].head(5)
# Out:
# 0    646.0
# 1    854.0
# 2    576.0
# 3    438.0
# 4    956.0
# Name: Area Income, dtype: float64

# %%
spf.rank()["Area Income"].tail(5)
# Out:
# 995    915.0
# 996    840.0
# 997    179.0
# 998    171.0
# 999     59.0
# Name: Area Income, dtype: float64

# %%
spf[(spf["Area Income"] >= 70000) & (spf["Male"] == 1)]
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 65                      62.42   29     73910.90                198.50
# 72                      55.35   39     75509.61                153.17
# 114                     69.00   32     72683.35                221.21
# 139                     75.80   38     70575.60                146.19
# 160                     76.32   35     74166.24                195.31
# 171                     71.84   47     76003.47                199.79
# 198                     73.41   31     73049.30                201.26
# 203                     70.04   31     74780.74                183.85
# 213                     67.28   43     76246.96                155.80
# 230                     66.67   33     72707.87                228.03
# 262                     59.21   35     73347.67                144.62
# 271                     73.04   37     73687.50                221.79
# ...

# %%
spf[(spf["Area Income"] >= 70000) & (spf["Male"] == 1)].index
# Out:
# Index([ 65,  72, 114, 139, 160, 171, 198, 203, 213, 230, 262, 271, 292, 294,
#        310, 338, 353, 364, 366, 388, 398, 419, 426, 458, 475, 481, 492, 505,
#        535, 539, 540, 549, 568, 677, 694, 708, 711, 718, 738, 742, 755, 780,
#        798, 843, 877, 924, 946, 948, 995],
#       dtype='int64')

# %%
len(spf[(spf["Area Income"] >= 70000) & (spf["Male"] == 1)].index)
# Out:
# 49

# %%
spf[(spf["Area Income"] >= 70000) & (spf["Male"] == 1)].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 49 entries, 65 to 995
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Daily Time Spent on Site  49 non-null     float64
#  1   Age                       49 non-null     int64
#  2   Area Income               49 non-null     float64
#  3   Daily Internet Usage      49 non-null     float64
#  4   Ad Topic Line             49 non-null     object
#  5   City                      49 non-null     object
#  6   Male                      49 non-null     int64
#  7   Country                   49 non-null     object
#  8   Timestamp                 49 non-null     object
#  9   Clicked on Ad             49 non-null     int64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 4.2+ KB

# %%
spf[(spf["Age"] >= 50) & (spf["City"]== spf["City"][0]=="T")]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5392\1327337491.py in ?()
# ----> 1 spf[(spf["Age"] >= 50) & (spf["City"]== spf["City"][0]=="T")]
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self)
#    1464     @final
#    1465     def __nonzero__(self) -> NoReturn:
# -> 1466         raise ValueError(
#    1467             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1468             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1469         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
spf[(spf["Age"] >= 50) & (spf["City"]== spf["City"][0]=="T")]
